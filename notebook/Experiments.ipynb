# %% [markdown]
# # load and display dataset

# %%
import pandas as pd

data = pd.read_csv(r"adult 3.csv")
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.shape
# Out:
# (48842, 14)

# %% [markdown]
# # Distribution of unique values of categorical columns in dataset

# %%
print(data.occupation.value_counts())
print("--------------------------------")
print(data.education.value_counts())
print("---------------------------------")
print(data.workclass.value_counts())
print("---------------------------------")
print(data.occupation.value_counts())
print("---------------------------------")
print(data.relationship.value_counts())
print("---------------------------------")
print(data.race.value_counts())
print("---------------------------------")
print(data.gender.value_counts())
print("---------------------------------")
print(data.income.value_counts())
print("---------------------------------")
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64
# --------------------------------
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64
# ---------------------------------
# workclass
# Private             33906
# ...

# %% [markdown]
# #  dataset cleaning process

# %%
data.occupation.replace({'?':'others'},inplace=True)
print(data.occupation.value_counts())
data.workclass.replace({'?':'others'},inplace=True)
print(data.workclass.value_counts())
data.education.replace({'?':'others'},inplace=True)
print(data.education.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# ...

# %%
#redundancy
data.drop(columns=['education'],inplace=True)
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18        others  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %% [markdown]
# # Data visualization

# %%
#outlier
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.boxplot(data['fnlwgt'])
plt.boxplot(data['capital-gain'])
plt.boxplot(data['capital-loss'])
plt.boxplot(data['hours-per-week'])
plt.boxplot(data['educational-num'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=data.drop(columns=['income']) #input
y=data['income'] #output
x
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18        others  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() # Initialize the LabelEncoder
x['workclass'] = le.fit_transform(x['workclass'])
x['capital-gain'] = le.fit_transform(x['capital-gain'])
x['capital-loss'] = le.fit_transform(x['capital-loss'])
x['hours-per-week'] = le.fit_transform(x['hours-per-week'])
x['educational-num'] = le.fit_transform(x['educational-num'])
x['marital-status'] = le.fit_transform(x['marital-status'])
x['fnlwgt'] = le.fit_transform(x['fnlwgt'])
x['race'] = le.fit_transform(x['race'])
x['relationship'] = le.fit_transform(x['relationship'])
x['gender'] = le.fit_transform(x['gender'])
x['native-country'] = le.fit_transform(x['native-country'])
x['occupation'] = le.fit_transform(x['occupation'])
x['age'] = le.fit_transform(x['age'])
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0        8          3   19329                6               4           6
# 1       21          3    4212                8               2           4
# 2       11          1   25340               11               2          10
# 3       27          3   11201                9               2           6
# 4        1          8    5411                9               4          14
# ...    ...        ...     ...              ...             ...         ...
# 48837   10          3   21582               11               2          12
# 48838   23          3   10584                8               2           6
# 48839   41          3   10316                8               6           0
# 48840    5          3   16813                8               4           0
# 48841   35          4   23321                8               2           3
#
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Split the data (X and y are already defined and preprocessed in previous cells)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
}

results = {}

for name, model in models.items():
    pipe = Pipeline([
        ('model', model)
    ])

    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(y_test, y_pred))
# Out:
# c:\Users\surya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression Accuracy: 0.7963
#               precision    recall  f1-score   support
#
#        <=50K       0.82      0.94      0.88      7479
#         >50K       0.63      0.32      0.42      2290
#
#     accuracy                           0.80      9769
#    macro avg       0.72      0.63      0.65      9769
# weighted avg       0.77      0.80      0.77      9769
#
# RandomForest Accuracy: 0.8646
#               precision    recall  f1-score   support
#
# ...

# %%
for name, score in results.items():
    print(f"{name} Accuracy: {score:.4f}")
# Out:
# c:\Users\surya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression: 0.7963
# RandomForest: 0.8654

# %%
import matplotlib.pyplot as plt
plt.bar(results.keys(), results.values(), color=['blue', 'red'])    
plt.ylabel('Accuracy Score')
plt.title('Comparison of Model Accuracy')   
plt.grid(True)
plt.show()

best_model_name = max(results, key=results.get)
best_model = models[best_model_name]
print(f"\n Best model: {best_model_name} with accuracy {results[best_model_name]:.4f}")
# Out:
#  Best model: RandomForest with accuracy 0.8654
